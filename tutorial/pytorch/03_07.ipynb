# %%
import torch
import torch.nn.functional as F
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

# %%
# Dataset 상속
class CustomDataset(Dataset): 
  def __init__(self):
    self.x_data = [[73, 80, 75],
                   [93, 88, 93],
                   [89, 91, 90],
                   [96, 98, 100],
                   [73, 66, 70]]
    self.y_data = [[152], [185], [180], [196], [142]]

  # 총 데이터의 개수를 리턴
  def __len__(self): 
    return len(self.x_data)

  # 인덱스를 입력받아 그에 맵핑되는 입출력 데이터를 파이토치의 Tensor 형태로 리턴
  def __getitem__(self, idx): 
    x = torch.FloatTensor(self.x_data[idx])
    y = torch.FloatTensor(self.y_data[idx])
    return x, y

# %%
dataset = CustomDataset()
dataloader = DataLoader(dataset, batch_size=2, shuffle=True)

# %%
model = torch.nn.Linear(3,1)
optimizer = torch.optim.SGD(model.parameters(), lr=1e-5)

# %%
nb_epochs = 100
for epoch in range(nb_epochs + 1):
  for batch_idx, samples in enumerate(dataloader):
    # print(batch_idx)
    # print(samples)
    x_train, y_train = samples
    # H(x) 계산
    prediction = model(x_train)

    # cost 계산
    cost = F.mse_loss(prediction, y_train)

    # cost로 H(x) 계산
    optimizer.zero_grad()
    cost.backward()
    optimizer.step()

    print('Epoch {:4d}/{} Batch {}/{} Cost: {:.6f}'.format(
        epoch, nb_epochs, batch_idx+1, len(dataloader),
        cost.item()
        ))
# Out:
# Epoch    0/100 Batch 1/3 Cost: 4.381416
# Epoch    0/100 Batch 2/3 Cost: 5.204613
# Epoch    0/100 Batch 3/3 Cost: 1.882033
# Epoch    1/100 Batch 1/3 Cost: 4.807087
# Epoch    1/100 Batch 2/3 Cost: 1.794899
# Epoch    1/100 Batch 3/3 Cost: 5.609936
# Epoch    2/100 Batch 1/3 Cost: 1.929821
# Epoch    2/100 Batch 2/3 Cost: 4.419446
# Epoch    2/100 Batch 3/3 Cost: 9.158437
# Epoch    3/100 Batch 1/3 Cost: 5.338069
# Epoch    3/100 Batch 2/3 Cost: 2.875803
# Epoch    3/100 Batch 3/3 Cost: 0.000014
# Epoch    4/100 Batch 1/3 Cost: 3.046573
# Epoch    4/100 Batch 2/3 Cost: 2.442734
# Epoch    4/100 Batch 3/3 Cost: 6.322690
# Epoch    5/100 Batch 1/3 Cost: 3.611205
# Epoch    5/100 Batch 2/3 Cost: 3.284529
# Epoch    5/100 Batch 3/3 Cost: 9.393959
# Epoch    6/100 Batch 1/3 Cost: 4.104215
# Epoch    6/100 Batch 2/3 Cost: 2.625815
# Epoch    6/100 Batch 3/3 Cost: 3.509848
# Epoch    7/100 Batch 1/3 Cost: 4.084223
# Epoch    7/100 Batch 2/3 Cost: 3.740026
# Epoch    7/100 Batch 3/3 Cost: 0.001716
# Epoch    8/100 Batch 1/3 Cost: 2.997772
# Epoch    8/100 Batch 2/3 Cost: 2.425824
# Epoch    8/100 Batch 3/3 Cost: 6.311261
# Epoch    9/100 Batch 1/3 Cost: 1.111865
# Epoch    9/100 Batch 2/3 Cost: 6.919425
# Epoch    9/100 Batch 3/3 Cost: 3.803024
# Epoch   10/100 Batch 1/3 Cost: 5.575437
# Epoch   10/100 Batch 2/3 Cost: 2.414762
# Epoch   10/100 Batch 3/3 Cost: 0.258246
# Epoch   11/100 Batch 1/3 Cost: 3.619173
# Epoch   11/100 Batch 2/3 Cost: 3.216476
# Epoch   11/100 Batch 3/3 Cost: 5.465804
# Epoch   12/100 Batch 1/3 Cost: 6.042680
# Epoch   12/100 Batch 2/3 Cost: 0.918766
# Epoch   12/100 Batch 3/3 Cost: 3.806774
# Epoch   13/100 Batch 1/3 Cost: 2.022576
# Epoch   13/100 Batch 2/3 Cost: 6.747916
# Epoch   13/100 Batch 3/3 Cost: 3.544925
# Epoch   14/100 Batch 1/3 Cost: 5.015682
# Epoch   14/100 Batch 2/3 Cost: 0.921137
# Epoch   14/100 Batch 3/3 Cost: 4.300548
# Epoch   15/100 Batch 1/3 Cost: 5.450610
# Epoch   15/100 Batch 2/3 Cost: 1.048514
# Epoch   15/100 Batch 3/3 Cost: 3.492147
# Epoch   16/100 Batch 1/3 Cost: 3.126827
# Epoch   16/100 Batch 2/3 Cost: 4.567263
# Epoch   16/100 Batch 3/3 Cost: 5.151188
# Epoch   17/100 Batch 1/3 Cost: 4.174664
# Epoch   17/100 Batch 2/3 Cost: 3.705148
# Epoch   17/100 Batch 3/3 Cost: 0.216321
# Epoch   18/100 Batch 1/3 Cost: 3.691290
# Epoch   18/100 Batch 2/3 Cost: 2.912428
# Epoch   18/100 Batch 3/3 Cost: 3.133023
# Epoch   19/100 Batch 1/3 Cost: 3.602408
# Epoch   19/100 Batch 2/3 Cost: 3.260831
# Epoch   19/100 Batch 3/3 Cost: 2.886878
# Epoch   20/100 Batch 1/3 Cost: 3.445663
# Epoch   20/100 Batch 2/3 Cost: 2.381063
# Epoch   20/100 Batch 3/3 Cost: 5.848123
# Epoch   21/100 Batch 1/3 Cost: 3.603603
# Epoch   21/100 Batch 2/3 Cost: 5.041394
# Epoch   21/100 Batch 3/3 Cost: 0.029415
# Epoch   22/100 Batch 1/3 Cost: 3.114645
# Epoch   22/100 Batch 2/3 Cost: 2.369188
# Epoch   22/100 Batch 3/3 Cost: 6.060345
# Epoch   23/100 Batch 1/3 Cost: 7.954607
# Epoch   23/100 Batch 2/3 Cost: 1.669432
# Epoch   23/100 Batch 3/3 Cost: 4.063113
# Epoch   24/100 Batch 1/3 Cost: 4.331591
# Epoch   24/100 Batch 2/3 Cost: 4.352867
# Epoch   24/100 Batch 3/3 Cost: 2.293513
# Epoch   25/100 Batch 1/3 Cost: 4.323642
# Epoch   25/100 Batch 2/3 Cost: 1.963759
# Epoch   25/100 Batch 3/3 Cost: 5.243790
# Epoch   26/100 Batch 1/3 Cost: 5.099609
# Epoch   26/100 Batch 2/3 Cost: 2.426058
# Epoch   26/100 Batch 3/3 Cost: 4.865735
# Epoch   27/100 Batch 1/3 Cost: 5.218802
# Epoch   27/100 Batch 2/3 Cost: 1.736683
# Epoch   27/100 Batch 3/3 Cost: 5.677723
# Epoch   28/100 Batch 1/3 Cost: 5.786819
# Epoch   28/100 Batch 2/3 Cost: 2.357015
# Epoch   28/100 Batch 3/3 Cost: 0.364507
# Epoch   29/100 Batch 1/3 Cost: 3.704627
# Epoch   29/100 Batch 2/3 Cost: 5.376844
# Epoch   29/100 Batch 3/3 Cost: 1.819469
# Epoch   30/100 Batch 1/3 Cost: 2.790472
# Epoch   30/100 Batch 2/3 Cost: 4.915064
# Epoch   30/100 Batch 3/3 Cost: 2.072552
# Epoch   31/100 Batch 1/3 Cost: 2.968338
# Epoch   31/100 Batch 2/3 Cost: 1.815304
# Epoch   31/100 Batch 3/3 Cost: 8.173931
# Epoch   32/100 Batch 1/3 Cost: 3.444691
# Epoch   32/100 Batch 2/3 Cost: 4.183307
# Epoch   32/100 Batch 3/3 Cost: 0.107906
# Epoch   33/100 Batch 1/3 Cost: 1.404994
# Epoch   33/100 Batch 2/3 Cost: 3.478810
# Epoch   33/100 Batch 3/3 Cost: 6.560073
# Epoch   34/100 Batch 1/3 Cost: 5.289855
# Epoch   34/100 Batch 2/3 Cost: 2.459616
# Epoch   34/100 Batch 3/3 Cost: 2.349262
# Epoch   35/100 Batch 1/3 Cost: 3.661916
# Epoch   35/100 Batch 2/3 Cost: 2.336981
# Epoch   35/100 Batch 3/3 Cost: 5.549527
# Epoch   36/100 Batch 1/3 Cost: 5.402183
# Epoch   36/100 Batch 2/3 Cost: 0.603573
# Epoch   36/100 Batch 3/3 Cost: 5.264915
# Epoch   37/100 Batch 1/3 Cost: 4.049350
# Epoch   37/100 Batch 2/3 Cost: 2.433116
# Epoch   37/100 Batch 3/3 Cost: 3.314760
# Epoch   38/100 Batch 1/3 Cost: 1.832204
# Epoch   38/100 Batch 2/3 Cost: 3.086061
# Epoch   38/100 Batch 3/3 Cost: 6.309804
# Epoch   39/100 Batch 1/3 Cost: 1.835524
# Epoch   39/100 Batch 2/3 Cost: 6.546774
# Epoch   39/100 Batch 3/3 Cost: 3.739080
# Epoch   40/100 Batch 1/3 Cost: 0.875714
# Epoch   40/100 Batch 2/3 Cost: 3.382421
# Epoch   40/100 Batch 3/3 Cost: 7.658813
# Epoch   41/100 Batch 1/3 Cost: 0.578394
# Epoch   41/100 Batch 2/3 Cost: 5.110690
# Epoch   41/100 Batch 3/3 Cost: 4.461831
# Epoch   42/100 Batch 1/3 Cost: 5.204301
# Epoch   42/100 Batch 2/3 Cost: 1.050135
# Epoch   42/100 Batch 3/3 Cost: 3.266156
# Epoch   43/100 Batch 1/3 Cost: 3.797329
# Epoch   43/100 Batch 2/3 Cost: 2.379001
# Epoch   43/100 Batch 3/3 Cost: 4.742992
# Epoch   44/100 Batch 1/3 Cost: 1.943912
# Epoch   44/100 Batch 2/3 Cost: 5.929457
# Epoch   44/100 Batch 3/3 Cost: 4.022186
# Epoch   45/100 Batch 1/3 Cost: 2.343360
# Epoch   45/100 Batch 2/3 Cost: 1.954784
# Epoch   45/100 Batch 3/3 Cost: 7.878088
# Epoch   46/100 Batch 1/3 Cost: 6.786487
# Epoch   46/100 Batch 2/3 Cost: 3.524274
# Epoch   46/100 Batch 3/3 Cost: 1.336985
# Epoch   47/100 Batch 1/3 Cost: 3.278205
# Epoch   47/100 Batch 2/3 Cost: 3.299552
# Epoch   47/100 Batch 3/3 Cost: 5.458030
# Epoch   48/100 Batch 1/3 Cost: 3.957965
# Epoch   48/100 Batch 2/3 Cost: 4.272525
# Epoch   48/100 Batch 3/3 Cost: 0.002792
# Epoch   49/100 Batch 1/3 Cost: 1.846934
# Epoch   49/100 Batch 2/3 Cost: 6.535460
# Epoch   49/100 Batch 3/3 Cost: 3.239077
# Epoch   50/100 Batch 1/3 Cost: 3.739747
# Epoch   50/100 Batch 2/3 Cost: 1.264616
# Epoch   50/100 Batch 3/3 Cost: 6.187292
# Epoch   51/100 Batch 1/3 Cost: 5.175657
# Epoch   51/100 Batch 2/3 Cost: 2.457518
# Epoch   51/100 Batch 3/3 Cost: 2.239986
# Epoch   52/100 Batch 1/3 Cost: 1.376769
# Epoch   52/100 Batch 2/3 Cost: 7.141283
# Epoch   52/100 Batch 3/3 Cost: 3.003295
# Epoch   53/100 Batch 1/3 Cost: 2.521958
# Epoch   53/100 Batch 2/3 Cost: 4.723130
# Epoch   53/100 Batch 3/3 Cost: 0.010029
# Epoch   54/100 Batch 1/3 Cost: 1.538619
# Epoch   54/100 Batch 2/3 Cost: 4.219749
# Epoch   54/100 Batch 3/3 Cost: 7.610917
# Epoch   55/100 Batch 1/3 Cost: 3.283558
# Epoch   55/100 Batch 2/3 Cost: 3.825463
# Epoch   55/100 Batch 3/3 Cost: 3.759407
# Epoch   56/100 Batch 1/3 Cost: 5.562080
# Epoch   56/100 Batch 2/3 Cost: 3.359963
# Epoch   56/100 Batch 3/3 Cost: 2.049770
# Epoch   57/100 Batch 1/3 Cost: 5.603858
# Epoch   57/100 Batch 2/3 Cost: 1.790757
# Epoch   57/100 Batch 3/3 Cost: 2.828377
# Epoch   58/100 Batch 1/3 Cost: 4.485625
# Epoch   58/100 Batch 2/3 Cost: 1.418936
# Epoch   58/100 Batch 3/3 Cost: 5.634828
# Epoch   59/100 Batch 1/3 Cost: 5.451079
# Epoch   59/100 Batch 2/3 Cost: 2.231839
# Epoch   59/100 Batch 3/3 Cost: 0.353210
# Epoch   60/100 Batch 1/3 Cost: 2.360541
# Epoch   60/100 Batch 2/3 Cost: 2.826611
# Epoch   60/100 Batch 3/3 Cost: 5.750014
# Epoch   61/100 Batch 1/3 Cost: 1.575772
# Epoch   61/100 Batch 2/3 Cost: 8.791279
# Epoch   61/100 Batch 3/3 Cost: 0.037897
# Epoch   62/100 Batch 1/3 Cost: 2.363441
# Epoch   62/100 Batch 2/3 Cost: 4.686767
# Epoch   62/100 Batch 3/3 Cost: 0.027293
# Epoch   63/100 Batch 1/3 Cost: 2.848098
# Epoch   63/100 Batch 2/3 Cost: 4.582515
# Epoch   63/100 Batch 3/3 Cost: 2.779626
# Epoch   64/100 Batch 1/3 Cost: 2.510264
# Epoch   64/100 Batch 2/3 Cost: 4.693827
# Epoch   64/100 Batch 3/3 Cost: 2.593281
# Epoch   65/100 Batch 1/3 Cost: 2.378128
# Epoch   65/100 Batch 2/3 Cost: 4.037589
# Epoch   65/100 Batch 3/3 Cost: 6.038952
# Epoch   66/100 Batch 1/3 Cost: 2.329386
# Epoch   66/100 Batch 2/3 Cost: 3.891308
# Epoch   66/100 Batch 3/3 Cost: 6.100605
# Epoch   67/100 Batch 1/3 Cost: 1.707943
# Epoch   67/100 Batch 2/3 Cost: 6.897457
# Epoch   67/100 Batch 3/3 Cost: 2.003934
# Epoch   68/100 Batch 1/3 Cost: 4.005512
# Epoch   68/100 Batch 2/3 Cost: 1.574577
# Epoch   68/100 Batch 3/3 Cost: 5.554057
# Epoch   69/100 Batch 1/3 Cost: 3.456948
# Epoch   69/100 Batch 2/3 Cost: 3.485353
# Epoch   69/100 Batch 3/3 Cost: 4.944136
# Epoch   70/100 Batch 1/3 Cost: 0.830210
# Epoch   70/100 Batch 2/3 Cost: 6.448995
# Epoch   70/100 Batch 3/3 Cost: 3.766570
# Epoch   71/100 Batch 1/3 Cost: 4.034142
# Epoch   71/100 Batch 2/3 Cost: 4.773145
# Epoch   71/100 Batch 3/3 Cost: 3.694190
# Epoch   72/100 Batch 1/3 Cost: 4.584768
# Epoch   72/100 Batch 2/3 Cost: 2.320403
# Epoch   72/100 Batch 3/3 Cost: 0.076017
# Epoch   73/100 Batch 1/3 Cost: 3.451685
# Epoch   73/100 Batch 2/3 Cost: 2.535024
# Epoch   73/100 Batch 3/3 Cost: 4.445537
# Epoch   74/100 Batch 1/3 Cost: 4.003472
# Epoch   74/100 Batch 2/3 Cost: 3.286954
# Epoch   74/100 Batch 3/3 Cost: 0.257022
# Epoch   75/100 Batch 1/3 Cost: 2.251893
# Epoch   75/100 Batch 2/3 Cost: 4.628355
# Epoch   75/100 Batch 3/3 Cost: 0.046302
# Epoch   76/100 Batch 1/3 Cost: 4.039783
# Epoch   76/100 Batch 2/3 Cost: 4.686895
# Epoch   76/100 Batch 3/3 Cost: 1.521008
# Epoch   77/100 Batch 1/3 Cost: 6.379374
# Epoch   77/100 Batch 2/3 Cost: 4.725644
# Epoch   77/100 Batch 3/3 Cost: 0.121981
# Epoch   78/100 Batch 1/3 Cost: 1.553292
# Epoch   78/100 Batch 2/3 Cost: 6.574452
# Epoch   78/100 Batch 3/3 Cost: 2.943254
# Epoch   79/100 Batch 1/3 Cost: 0.739203
# Epoch   79/100 Batch 2/3 Cost: 4.602603
# Epoch   79/100 Batch 3/3 Cost: 3.684811
# Epoch   80/100 Batch 1/3 Cost: 4.028065
# Epoch   80/100 Batch 2/3 Cost: 3.615174
# Epoch   80/100 Batch 3/3 Cost: 2.577383
# Epoch   81/100 Batch 1/3 Cost: 5.267694
# Epoch   81/100 Batch 2/3 Cost: 0.932176
# Epoch   81/100 Batch 3/3 Cost: 3.179650
# Epoch   82/100 Batch 1/3 Cost: 2.338980
# Epoch   82/100 Batch 2/3 Cost: 4.539404
# Epoch   82/100 Batch 3/3 Cost: 0.023255
# Epoch   83/100 Batch 1/3 Cost: 2.314041
# Epoch   83/100 Batch 2/3 Cost: 4.540288
# Epoch   83/100 Batch 3/3 Cost: 0.026977
# Epoch   84/100 Batch 1/3 Cost: 0.830510
# Epoch   84/100 Batch 2/3 Cost: 5.087414
# Epoch   84/100 Batch 3/3 Cost: 7.257390
# Epoch   85/100 Batch 1/3 Cost: 2.846194
# Epoch   85/100 Batch 2/3 Cost: 3.093168
# Epoch   85/100 Batch 3/3 Cost: 7.983108
# Epoch   86/100 Batch 1/3 Cost: 4.443868
# Epoch   86/100 Batch 2/3 Cost: 2.344851
# Epoch   86/100 Batch 3/3 Cost: 4.414513
# Epoch   87/100 Batch 1/3 Cost: 2.980587
# Epoch   87/100 Batch 2/3 Cost: 4.596059
# Epoch   87/100 Batch 3/3 Cost: 2.348654
# Epoch   88/100 Batch 1/3 Cost: 2.586572
# Epoch   88/100 Batch 2/3 Cost: 3.504617
# Epoch   88/100 Batch 3/3 Cost: 4.876781
# Epoch   89/100 Batch 1/3 Cost: 1.687572
# Epoch   89/100 Batch 2/3 Cost: 6.358299
# Epoch   89/100 Batch 3/3 Cost: 3.412762
# Epoch   90/100 Batch 1/3 Cost: 4.149180
# Epoch   90/100 Batch 2/3 Cost: 3.149341
# Epoch   90/100 Batch 3/3 Cost: 0.313751
# Epoch   91/100 Batch 1/3 Cost: 2.313404
# Epoch   91/100 Batch 2/3 Cost: 2.121487
# Epoch   91/100 Batch 3/3 Cost: 5.985674
# Epoch   92/100 Batch 1/3 Cost: 4.837595
# Epoch   92/100 Batch 2/3 Cost: 0.521773
# Epoch   92/100 Batch 3/3 Cost: 4.893171
# Epoch   93/100 Batch 1/3 Cost: 4.663027
# Epoch   93/100 Batch 2/3 Cost: 3.360372
# Epoch   93/100 Batch 3/3 Cost: 2.154628
# Epoch   94/100 Batch 1/3 Cost: 2.651204
# Epoch   94/100 Batch 2/3 Cost: 4.514089
# Epoch   94/100 Batch 3/3 Cost: 2.443552
# Epoch   95/100 Batch 1/3 Cost: 6.033150
# Epoch   95/100 Batch 2/3 Cost: 1.771588
# Epoch   95/100 Batch 3/3 Cost: 3.951018
# Epoch   96/100 Batch 1/3 Cost: 4.926204
# Epoch   96/100 Batch 2/3 Cost: 1.585358
# Epoch   96/100 Batch 3/3 Cost: 4.957716
# Epoch   97/100 Batch 1/3 Cost: 2.606751
# Epoch   97/100 Batch 2/3 Cost: 3.479396
# Epoch   97/100 Batch 3/3 Cost: 4.771081
# Epoch   98/100 Batch 1/3 Cost: 1.286435
# Epoch   98/100 Batch 2/3 Cost: 8.619708
# Epoch   98/100 Batch 3/3 Cost: 0.063112
# Epoch   99/100 Batch 1/3 Cost: 4.393882
# Epoch   99/100 Batch 2/3 Cost: 0.799024
# Epoch   99/100 Batch 3/3 Cost: 3.866189
# Epoch  100/100 Batch 1/3 Cost: 1.883354
# Epoch  100/100 Batch 2/3 Cost: 3.628886
# Epoch  100/100 Batch 3/3 Cost: 5.786074

# %%
# 임의의 입력 [73, 80, 75]를 선언
new_var =  torch.FloatTensor([[73, 80, 75]]) 
# 입력한 값 [73, 80, 75]에 대해서 예측값 y를 리턴받아서 pred_y에 저장
pred_y = model(new_var) 
print("훈련 후 입력이 73, 80, 75일 때의 예측값 :", pred_y)
# Out:
# 훈련 후 입력이 73, 80, 75일 때의 예측값 : tensor([[154.4063]], grad_fn=<AddmmBackward0>)
